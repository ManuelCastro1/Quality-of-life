# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelCastro1/Quality-of-life/blob/main/idh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go


datos = pd.read_csv("ejemplolibertadeconomica.csv")
pais = datos["País"].values
calidad_de_vida = datos["Índice de Calidad de Vida"].str.replace(",",".").astype(float)
costo_de_vida = datos["Índice de Costo de Vida"].str.replace(",",".").astype(float)

correlacion = np.corrcoef(calidad_de_vida,costo_de_vida)
correlacion = correlacion[0,1]

fig = go.Figure()
fig.add_trace(
    go.Scatter(x=calidad_de_vida, y = costo_de_vida, mode="markers",text=pais)
    )

factor = np.min(costo_de_vida)-np.min(calidad_de_vida)

fig.add_trace(
    go.Scatter(x=calidad_de_vida, y = (calidad_de_vida*correlacion+factor))
)
fig.update_traces(textposition='top center')

print(np.where(pais=="Nigeria"))

fig.add_annotation(x=calidad_de_vida[67], y=costo_de_vida[67],   text="Colombia", showarrow=True, arrowhead=1)
fig.add_annotation(x=calidad_de_vida[1], y=costo_de_vida[1],   text="Dinamarca", showarrow=True, arrowhead=1)
fig.add_annotation(x=calidad_de_vida[82], y=costo_de_vida[82],   text="Nigeria", showarrow=True, arrowhead=1)

fig.update_xaxes(title="Índice de Calidad de Vida")
fig.update_yaxes(title="Índice de Costo de Vida")
fig.update_layout(showlegend=False)
fig.update_traces(selector=dict(type='scatter'), showlegend=False)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-21b1e7c5dc09> in <module>()
#       5
#       6
# ----> 7 datos = pd.read_csv("ejemplolibertadeconomica.csv")
#       8 pais = datos["País"].values
#       9 calidad_de_vida = datos["Índice de Calidad de Vida"].str.replace(",",".").astype(float)
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ejemplolibertadeconomica.csv'

# %%
datoslib = pd.read_csv("ejemplolibertadeconomica2.csv")
 
paises = datoslib.values
paises = paises[:,0]
listapaises = []
a = 0
while a < len(paises):
  pais = paises[a]
  if isinstance(pais,str):
    pais = pais.split("\xa0", 1)[0]
    listapaises.append(pais)
  
  
  a = a +1
 
datos = pd.read_csv("ejemplolibertadeconomica.csv")
pais = datos["País"].values
calidad_de_vida = datos["Índice de Calidad de Vida"].str.replace(",",".").astype(float)
 
listalibertad = []
paisesdef = []
calidadvida = []
i = 0
while i < len(listapaises):
  a = 0
  while a < len(pais):
    if listapaises[i] ==  pais[a]:
      listalibertad.append(datoslib.values[i,1])
      paisesdef.append(listapaises[i])
      calidadvida.append(calidad_de_vida[a].astype(float))
      
 
      a = len(pais)
    a = a +1
  i = i +1
 
 
 
listalibertad = np.asarray(listalibertad)
calidadvida = np.asarray(calidadvida)
correlacion = np.corrcoef(calidadvida,listalibertad)
correlacion = correlacion[0,1]
 
fig = go.Figure()
fig.add_trace(
    go.Scatter(x=listalibertad, y = calidadvida, mode="markers",text=paisesdef)
    )
 
 
factor = (np.max(calidadvida)-np.min(calidadvida))/2
fig.add_trace(
    go.Scatter(x=listalibertad, y = (listalibertad*correlacion+factor))
)
 
fig.update_xaxes(title="Índice de libertad económica")
fig.update_yaxes(title="Índice de Calidad de Vida")
fig.update_layout(showlegend=False)
fig.update_traces(selector=dict(type='scatter'), showlegend=False)
 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="108c38a4-61a0-4ffa-bb09-1afd9cad4626" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("108c38a4-61a0-4ffa-bb09-1afd9cad4626")) {
#                     Plotly.newPlot(
#                         '108c38a4-61a0-4ffa-bb09-1afd9cad4626',
#                         [{"mode": "markers", "showlegend": false, "text": ["Hong Kong", "Singapur", "Nueva Zelanda", "Suiza", "Estonia", "Canad\u00e1", "Chile", "Reino Unido", "Georgia", "Pa\u00edses Bajos", "Lituania", "Dinamarca", "Letonia", "Islandia", "Corea del Sur", "Finlandia", "Alemania", "Malasia", "Rep\u00fablica Checa", "Catar", "Austria", "Macedonia del Norte", "Israel", "Colombia", "Jap\u00f3n", "Polonia", "Bulgaria", "Chipre", "B\u00e9lgica", "Jordania", "Hungr\u00eda", "Filipinas", "Turqu\u00eda", "Kuwait", "Costa Rica", "Arabia Saudita", "Azerbaiy\u00e1n", "Espa\u00f1a", "Italia", "Om\u00e1n", "Indonesia", "Marruecos", "Bosnia y Herzegovina", "Croacia", "Serbia", "China", "Sri Lanka", "Nigeria", "Grecia", "Banglad\u00e9s", "Kenia", "L\u00edbano", "Brasil", "Pakist\u00e1n", "Egipto", "Vietnam", "Ir\u00e1n", "Ecuador"], "type": "scatter", "x": [89.8, 88.6, 83.7, 81.5, 79.1, 78.5, 76.5, 76.4, 76.0, 75.8, 75.8, 75.1, 74.8, 74.4, 74.3, 74.0, 73.8, 73.8, 73.3, 73.1, 72.3, 70.7, 69.7, 69.7, 69.6, 68.3, 67.9, 67.9, 67.8, 66.7, 65.8, 65.6, 65.2, 65.1, 65.0, 64.4, 63.6, 63.6, 62.5, 62.1, 61.9, 61.5, 60.2, 59.4, 58.9, 57.4, 57.4, 57.1, 55.0, 55.0, 53.5, 53.3, 52.9, 52.8, 52.6, 52.4, 50.5, 49.3], "y": [99.34, 143.82, 175.77, 190.82, 173.56, 159.99, 99.9, 158.99, 118.87, 183.31, 160.02, 190.01, 147.59, 179.1, 130.02, 182.79, 176.76, 116.94, 156.33, 154.58, 182.37, 108.47, 144.14, 101.33, 162.32, 132.65, 126.34, 144.06, 150.89, 114.04, 134.01, 78.39, 125.97, 113.98, 121.65, 147.37, 102.88, 164.48, 138.63, 172.08, 90.1, 104.42, 125.71, 156.1, 116.24, 103.15, 79.78, 52.0, 129.86, 65.27, 75.77, 94.47, 104.75, 105.14, 86.31, 88.38, 64.73, 118.76]}, {"showlegend": false, "type": "scatter", "x": [89.8, 88.6, 83.7, 81.5, 79.1, 78.5, 76.5, 76.4, 76.0, 75.8, 75.8, 75.1, 74.8, 74.4, 74.3, 74.0, 73.8, 73.8, 73.3, 73.1, 72.3, 70.7, 69.7, 69.7, 69.6, 68.3, 67.9, 67.9, 67.8, 66.7, 65.8, 65.6, 65.2, 65.1, 65.0, 64.4, 63.6, 63.6, 62.5, 62.1, 61.9, 61.5, 60.2, 59.4, 58.9, 57.4, 57.4, 57.1, 55.0, 55.0, 53.5, 53.3, 52.9, 52.8, 52.6, 52.4, 50.5, 49.3], "y": [123.30760311419752, 122.58736788327283, 119.64640735699702, 118.32597610030176, 116.88550563845237, 116.52538802299003, 115.32499597144889, 115.26497636887183, 115.0248979585636, 114.90485875340948, 114.90485875340948, 114.48472153537008, 114.30466272763891, 114.06458431733068, 114.00456471475363, 113.82450590702246, 113.70446670186834, 113.70446670186834, 113.40436868898306, 113.28432948382894, 112.80417266321248, 111.84385902197957, 111.243662996209, 111.243662996209, 111.18364339363193, 110.40338856013018, 110.16331014982197, 110.16331014982197, 110.1032905472449, 109.44307491889727, 108.90289849570374, 108.78285929054962, 108.54278088024141, 108.48276127766434, 108.42274167508728, 108.06262405962495, 107.58246723900848, 107.58246723900848, 106.92225161066085, 106.68217320035262, 106.56213399519851, 106.32205558489028, 105.54180075138854, 105.06164393077208, 104.76154591788679, 103.86125187923093, 103.86125187923093, 103.68119307149976, 102.42078141738156, 102.42078141738156, 101.52048737872569, 101.40044817357158, 101.16036976326335, 101.10035016068629, 100.98031095553218, 100.86027175037806, 99.71989930141397, 98.99966407048927]}],
#                         {"showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": "

# %%
import math

idhdat = pd.read_csv("Human Development Index (HDI).csv")
freedom = pd.read_csv("data.csv")
names = freedom.values[:,0]
countries = []
freedomindex = []
idh = []

a = 0
while a < len(names):
  name = str(names[a])
  #name = name.split(" ", 1)[0]
  j = 0
  while j < len(idhdat):
    found = str(idhdat.values[j,0])
    found = found[1:]
    

    if found == name and math.isnan(float(freedom.values[a,2])) == False:
      countries.append(name)
      freedomindex.append(float(freedom.values[a,2]))
      idh.append(float(idhdat.values[j,1]))

      
      j = len(idhdat)


      

    j = j +1

  a = a + 1


idh = (100*(np.asarray(idh).astype(float)))
freedomindex = (np.asarray(freedomindex).astype(float))

fig = go.Figure()
fig.add_trace(
    go.Scatter(x = freedomindex, y = idh, text=countries, mode="markers")
)


correlacion = np.corrcoef(freedomindex,idh)
correlacion = correlacion[0,1]
print(correlacion)



factor = (np.max(idh)-np.min(idh))/2

fig.add_trace(
    go.Scatter(x=freedomindex, y = (freedomindex*correlacion+factor), mode="lines")
)



fig.add_annotation(x=69.7, y=76.3,   text="Colombia", showarrow=True,  font=dict(family="Arial", size=16, color="#000000" ),   align="center",      arrowhead=2,        arrowsize=1,        arrowwidth=2,        arrowcolor="#000000",        ax=-10,        ay=-40,        bordercolor="#FFFFFF",        borderwidth=2,        borderpad=4,        bgcolor="#FFEA35",        opacity=0.99)
fig.add_annotation(x=75.1, y=93.6,   text="Dinamarca", showarrow=True,font=dict(family="Arial", size=16, color="#000000" ),   align="center",      arrowhead=2,        arrowsize=1,        arrowwidth=2,        arrowcolor="#000000",        ax=-10,        ay=-40,        bordercolor="#FFFFFF",        borderwidth=2,        borderpad=4,        bgcolor="#FF5656",        opacity=0.99)

fig.add_annotation(x=57.1, y=53.1,   text="Nigeria", showarrow=True, font=dict(family="Arial", size=16, color="#000000" ),   align="center",      arrowhead=2,        arrowsize=1,        arrowwidth=2,        arrowcolor="#000000",        ax=-10,        ay=-40,        bordercolor="#FFFFFF",        borderwidth=2,        borderpad=4,        bgcolor="#00834e",        opacity=0.99)
 
fig.update_xaxes(title="Índice de libertad económica")
fig.update_yaxes(title="Índice de desarrollo humano")
fig.update_layout(showlegend=False)
fig.update_traces(selector=dict(type='scatter'), showlegend=False)

fig.show()

# %%
datos = pd.read_excel("corrupcion.xlsx", sheet_name="Merged data")
datos = datos.dropna()


fig = go.Figure()
trendline = px.scatter(datos, x="Transparency", y="Quality of life", trendline="ols")
results = px.get_trendline_results(trendline)
trendline = trendline.data[1]
trendline["marker_color"] = "#FA636E"
fig.add_trace(go.Scatter( x = datos["Transparency"], y = datos["Quality of life"], mode = "markers", text=datos["Nation or Territory"], showlegend=False))
fig.add_trace(go.Scatter(trendline))
fig.update_xaxes(title="Transparency Index")
fig.update_yaxes(title="Quality of life Index")
fig.update_layout(title="Transparency vs. Quality of life")
fig.show()

correlation = np.corrcoef(datos["Transparency"],datos["Quality of life"])
print(correlation[0,1])
results.px_fit_results.iloc[0].summary()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="46e1c80f-ed18-4d1b-a86e-1f6603f1d87d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("46e1c80f-ed18-4d1b-a86e-1f6603f1d87d")) {
#                     Plotly.newPlot(
#                         '46e1c80f-ed18-4d1b-a86e-1f6603f1d87d',
#                         [{"mode": "markers", "showlegend": false, "text": ["Denmark", "New Zealand", "Finland", "Singapore", "Sweden", "Switzerland", "Norway", "Netherlands", "Germany", "Luxembourg", "Australia", "Canada", "Hong Kong", "United Kingdom", "Austria", "Belgium", "Estonia", "Iceland", "Japan", "Ireland", "United Arab Emirates", "Uruguay", "France", "Chile", "United States", "Seychelles", "Barbados", "Qatar", "Spain", "South Korea", "Portugal", "Botswana", "Israel", "Lithuania", "Slovenia", "Costa Rica", "Cyprus", "Latvia", "Georgia", "Poland", "Oman", "Rwanda", "Italy", "Malta", "Mauritius", "Saudi Arabia", "Malaysia", "Greece", "Armenia", "Jordan", "Belarus", "Croatia", "Bulgaria", "Hungary", "Jamaica", "Romania", "South Africa", "Tunisia", "Ghana", "Maldives", "Argentina", "Bahrain", "China", "Kuwait", "India", "Morocco", "Timor-Leste", "Trinidad and Tobago", "Turkey", "Colombia", "Ecuador", "Brazil", "Ethiopia", "Kazakhstan", "Peru", "Sri Lanka", "Tanzania", "Indonesia", "Albania", "Algeria", "El Salvador", "Thailand", "Vietnam", "Bosnia and Herzegovina", "Mongolia", "Moldova", "Philippines", "Egypt", "Nepal", "Sierra Leone", "Ukraine", "Zambia", "Bolivia", "Kenya", "Mexico", "Pakistan", "Azerbaijan", "Malawi", "Russia", "Laos", "Togo", "Dominican Republic", "Paraguay", "Angola", "Uganda", "Uzbekistan", "Cameroon", "Guatemala", "Iran", "Lebanon", "Mozambique", "Nigeria", "Tajikistan", "Honduras", "Zimbabwe", "Nicaragua", "Cambodia", "Afghanistan", "Burundi", "Equatorial Guinea", "Sudan"], "type": "scatter", "x": [88, 88, 85, 85, 85, 85, 84, 82, 80, 80, 77, 77, 77, 77, 76, 76, 75, 75, 74, 72, 71, 71, 69, 67, 67, 66, 64, 63, 62, 61, 61, 60, 60, 60, 60, 57, 57, 57, 56, 56, 54, 54, 53, 53, 53, 53, 51, 50, 49, 49, 47, 47, 44, 44, 44, 44, 44, 44, 43, 43, 42, 42, 42, 42, 40, 40, 40, 40, 40, 39, 39, 38, 38, 38, 38, 38, 38, 37, 36, 36, 36, 36, 36, 35, 35, 34, 34, 33, 33, 33, 33, 33, 31, 31, 31, 31, 30, 30, 30, 29, 29, 28, 28, 27, 27, 26, 25, 25, 25, 25, 25, 25, 25, 24, 24, 22, 21, 19, 19, 16, 16], "y": [68.0, 72.0, 69.0, 73.0, 70.0, 74.0, 70.0, 70.0, 71.0, 73.0, 79.0, 70.0, 75.0, 64.0, 70.0, 65.0, 64.0, 65.0, 70.0, 63.0, 69.0, 65.0, 70.0, 62.0, 71.0, 57.0, 63.0, 65.0, 72.0, 70.0, 71.0, 63.0, 67.0, 62.0, 66.0, 57.0, 70.0, 60.0, 58.0, 65.0, 61.0, 50.0, 66.0, 73.0, 63.0, 61.0, 59.0, 65.0, 54.0, 53.0, 50.0, 68.0, 63.0, 63.0, 48.0, 60.0, 52.0, 55.0, 48.0, 56.0, 59.0, 60.0, 57.0, 58.0, 50.0, 55.0, 49.0, 50.0, 53.0, 45.0, 55.0, 47.0, 43.0, 54.0, 56.0, 55.0, 48.0, 51.0, 54.0, 52.0, 44.0, 57.0, 53.0, 56.0, 54.0, 50.0, 46.0, 48.0, 48.0, 39.0, 48.0, 44.0, 52.0, 48.0, 52.0, 46.0, 50.0, 45.0, 51.0, 47.0, 41.0, 50.0, 55.0, 36.0, 45.0, 50.0, 33.0, 45.0, 43.0, 48.0, 42.0, 30.0, 44.0, 44.0, 40.0, 40.0, 46.0, 35.0, 43.0, 37.0, 29.0]}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>OLS trendline</b><br>Quality of life = 0.499602 * Transparency + 32.242020<br>R<sup>2</sup>=0.767759<br><br>Transparency=%{x}<br>Quality of life=%{y} <b>(trend)</b>", "legendgroup": "", "marker": {"color": "#FA636E", "symbol": "circle"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [16, 16, 19, 19, 21, 22, 24, 24, 25, 25, 25, 25, 25, 25, 25, 26, 27, 27, 28, 28, 29, 29, 30, 30, 30, 31, 31, 31, 31, 33, 33, 33, 33, 33, 34, 34, 35, 35, 36, 36, 36, 36, 36, 37, 38, 38, 38, 38, 38, 38, 39, 39, 40, 40, 40, 40, 40, 42, 42, 42, 42, 43, 43, 44, 44, 44, 44, 44, 44, 47, 47, 49, 49, 50, 51, 53, 53, 53, 53, 54, 54, 56, 56, 57, 57, 57, 60, 60, 60, 60, 61, 61, 62, 63, 64, 66, 67, 67, 69, 71, 71, 72, 74, 75, 75, 76, 76, 77, 77, 77, 77, 80, 80, 82, 84, 85, 85, 85, 85, 88, 88], "xaxis": "x", "y": [40.235656417337445, 40.235656417337445, 41.73446332923516, 41.73446332923516, 42.73366793716697, 43.23327024113288, 44.23247484906469, 44.23247484906469, 44.732077153030595, 44.732077153030595, 44.732077153030595, 44.732077153030595, 44.732077153030595, 44.732077153030595, 44.732077153030595, 45.2316794569965, 45.7312817609624, 45.7312817609624, 46.230 ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"
# 0.8762183728748296
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     393.4
# Date:                Tue, 11 May 2021   Prob (F-statistic):           1.56e-39
# Time:                        23:22:00   Log-Likelihood:                -372.86
# No. Observations:                 121   AIC:                             749.7
# Df Residuals:                     119   BIC:                             755.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         32.2420      1.290     24.999      0.000      29.688      34.796
# x1             0.4996      0.025     19.834      0.000       0.450       0.549
# ==============================================================================
# Omnibus:                        0.032   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.984   Jarque-Bera (JB):                0.090
# Skew:                          -0.038   Prob(JB):                        0.956
# Kurtosis:                       2.890   Cond. No.                         137.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
datos = pd.read_excel("corrupcion.xlsx", sheet_name="Merged data")
datos = datos.dropna()


fig = go.Figure()
trendline = px.scatter(datos, x="Economical Freedom", y="Quality of life", trendline="ols")
results = px.get_trendline_results(trendline)
trendline = trendline.data[1]
trendline["marker_color"] = "#FA636E"
fig.add_trace(go.Scatter( x = datos["Economical Freedom"], y = datos["Quality of life"], mode = "markers", text=datos["Nation or Territory"], showlegend=False))
fig.add_trace(go.Scatter(trendline))
fig.update_xaxes(title="Economical Freedom Index")
fig.update_yaxes(title="Quality of life Index")
fig.update_layout(title="Economical Freedom vs. Quality of life")
fig.show()

correlation = np.corrcoef(datos["Economical Freedom"],datos["Quality of life"])
print(correlation[0,1])
results.px_fit_results.iloc[0].summary()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="642f4018-614c-41f2-a09c-db7a5d8f1903" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("642f4018-614c-41f2-a09c-db7a5d8f1903")) {
#                     Plotly.newPlot(
#                         '642f4018-614c-41f2-a09c-db7a5d8f1903',
#                         [{"mode": "markers", "showlegend": false, "text": ["Denmark", "New Zealand", "Finland", "Singapore", "Sweden", "Switzerland", "Norway", "Netherlands", "Germany", "Luxembourg", "Australia", "Canada", "Hong Kong", "United Kingdom", "Austria", "Belgium", "Estonia", "Iceland", "Japan", "Ireland", "United Arab Emirates", "Uruguay", "France", "Chile", "United States", "Seychelles", "Barbados", "Qatar", "Spain", "South Korea", "Portugal", "Botswana", "Israel", "Lithuania", "Slovenia", "Costa Rica", "Cyprus", "Latvia", "Georgia", "Poland", "Oman", "Rwanda", "Italy", "Malta", "Mauritius", "Saudi Arabia", "Malaysia", "Greece", "Armenia", "Jordan", "Belarus", "Croatia", "Bulgaria", "Hungary", "Jamaica", "Romania", "South Africa", "Tunisia", "Ghana", "Maldives", "Argentina", "Bahrain", "China", "Kuwait", "India", "Morocco", "Timor-Leste", "Trinidad and Tobago", "Turkey", "Colombia", "Ecuador", "Brazil", "Ethiopia", "Kazakhstan", "Peru", "Sri Lanka", "Tanzania", "Indonesia", "Albania", "Algeria", "El Salvador", "Thailand", "Vietnam", "Bosnia and Herzegovina", "Mongolia", "Moldova", "Philippines", "Egypt", "Nepal", "Sierra Leone", "Ukraine", "Zambia", "Bolivia", "Kenya", "Mexico", "Pakistan", "Azerbaijan", "Malawi", "Russia", "Laos", "Togo", "Dominican Republic", "Paraguay", "Angola", "Uganda", "Uzbekistan", "Cameroon", "Guatemala", "Iran", "Lebanon", "Mozambique", "Nigeria", "Tajikistan", "Honduras", "Zimbabwe", "Nicaragua", "Cambodia", "Afghanistan", "Burundi", "Equatorial Guinea", "Sudan"], "type": "scatter", "x": [78.3, 84.1, 75.7, 89.4, 74.9, 82.0, 73.4, 77.0, 73.5, 75.8, 82.6, 78.2, 89.1, 79.3, 73.3, 68.9, 77.7, 77.1, 73.3, 80.9, 76.2, 69.1, 66.0, 76.8, 76.6, 64.3, 61.4, 72.3, 66.9, 74.0, 67.0, 69.6, 74.0, 76.7, 67.8, 65.8, 70.1, 71.9, 77.1, 69.1, 63.6, 70.9, 63.8, 69.5, 74.9, 62.4, 74.7, 59.9, 70.6, 66.0, 61.7, 62.2, 70.2, 66.4, 68.5, 69.7, 58.8, 55.8, 59.4, 56.5, 53.1, 66.3, 59.5, 63.2, 56.5, 63.3, 45.9, 58.3, 64.4, 69.2, 51.3, 53.7, 53.6, 69.6, 67.9, 57.4, 61.7, 67.2, 66.9, 46.9, 61.6, 69.4, 58.8, 62.6, 55.9, 62.0, 64.5, 54.0, 54.2, 48.0, 54.9, 53.5, 42.8, 55.3, 66.0, 54.8, 69.3, 52.8, 61.0, 55.5, 54.1, 60.9, 63.0, 52.2, 59.5, 57.2, 53.6, 64.0, 49.2, 51.7, 50.5, 57.2, 52.2, 61.1, 43.1, 57.2, 57.3, 54.7, 49.0, 48.3, 45.0], "y": [68.0, 72.0, 69.0, 73.0, 70.0, 74.0, 70.0, 70.0, 71.0, 73.0, 79.0, 70.0, 75.0, 64.0, 70.0, 65.0, 64.0, 65.0, 70.0, 63.0, 69.0, 65.0, 70.0, 62.0, 71.0, 57.0, 63.0, 65.0, 72.0, 70.0, 71.0, 63.0, 67.0, 62.0, 66.0, 57.0, 70.0, 60.0, 58.0, 65.0, 61.0, 50.0, 66.0, 73.0, 63.0, 61.0, 59.0, 65.0, 54.0, 53.0, 50.0, 68.0, 63.0, 63.0, 48.0, 60.0, 52.0, 55.0, 48.0, 56.0, 59.0, 60.0, 57.0, 58.0, 50.0, 55.0, 49.0, 50.0, 53.0, 45.0, 55.0, 47.0, 43.0, 54.0, 56.0, 55.0, 48.0, 51.0, 54.0, 52.0, 44.0, 57.0, 53.0, 56.0, 54.0, 50.0, 46.0, 48.0, 48.0, 39.0, 48.0, 44.0, 52.0, 48.0, 52.0, 46.0, 50.0, 45.0, 51.0, 47.0, 41.0, 50.0, 55.0, 36.0, 45.0, 50.0, 33.0, 45.0, 43.0, 48.0, 42.0, 30.0, 44.0, 44.0, 40.0, 40.0, 46.0, 35.0, 43.0, 37.0, 29.0]}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>OLS trendline</b><br>Quality of life = 0.852564 * Economical Freedom + 1.165561<br>R<sup>2</sup>=0.609055<br><br>Economical Freedom=%{x}<br>Quality of life=%{y} <b>(trend)</b>", "legendgroup": "", "marker": {"color": "#FA636E", "symbol": "circle"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [42.8, 43.1, 45.0, 45.9, 46.9, 48.0, 48.3, 49.0, 49.2, 50.5, 51.3, 51.7, 52.2, 52.2, 52.8, 53.1, 53.5, 53.6, 53.6, 53.7, 54.0, 54.1, 54.2, 54.7, 54.8, 54.9, 55.3, 55.5, 55.8, 55.9, 56.5, 56.5, 57.2, 57.2, 57.2, 57.3, 57.4, 58.3, 58.8, 58.8, 59.4, 59.5, 59.5, 59.9, 60.9, 61.0, 61.1, 61.4, 61.6, 61.7, 61.7, 62.0, 62.2, 62.4, 62.6, 63.0, 63.2, 63.3, 63.6, 63.8, 64.0, 64.3, 64.4, 64.5, 65.8, 66.0, 66.0, 66.0, 66.3, 66.4, 66.9, 66.9, 67.0, 67.2, 67.8, 67.9, 68.5, 68.9, 69.1, 69.1, 69.2, 69.3, 69.4, 69.5, 69.6, 69.6, 69.7, 70.1, 70.2, 70.6, 70.9, 71.9, 72.3, 73.3, 73.3, 73.4, 73.5, 74.0, 74.0, 74.7, 74.9,  ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}],
# 0.7804195933623976
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.609
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     185.4
# Date:                Tue, 11 May 2021   Prob (F-statistic):           5.01e-26
# Time:                        22:46:22   Log-Likelihood:                -404.37
# No. Observations:                 121   AIC:                             812.7
# Df Residuals:                     119   BIC:                             818.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1656      4.073      0.286      0.775      -6.899       9.230
# x1             0.8526      0.063     13.616      0.000       0.729       0.977
# ==============================================================================
# Omnibus:                        0.167   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.920   Jarque-Bera (JB):                0.278
# Skew:                          -0.081   Prob(JB):                        0.870
# Kurtosis:                       2.830   Cond. No.                         423.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
datos = pd.read_excel("corrupcion.xlsx", sheet_name="Merged data")
datos = datos.dropna()


fig = go.Figure()
trendline = px.scatter(datos, x="Economical Freedom", y="Transparency", trendline="ols")
results = px.get_trendline_results(trendline)
trendline = trendline.data[1]
trendline["marker_color"] = "#FA636E"
fig.add_trace(go.Scatter( x = datos["Economical Freedom"], y = datos["Transparency"], mode = "markers", text=datos["Nation or Territory"], showlegend=False, name="Country"))
fig.add_trace(go.Scatter(trendline))
fig.update_xaxes(title="Economical Freedom Index")
fig.update_yaxes(title="Transparency")
fig.update_layout(title="Economical Freedom vs. Transparency")
fig.show()

correlation = np.corrcoef(datos["Economical Freedom"],datos["Transparency"])
print(correlation[0,1])


results.px_fit_results.iloc[0].summary()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="74e19be1-93cb-4e39-91ec-d891821614d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("74e19be1-93cb-4e39-91ec-d891821614d9")) {
#                     Plotly.newPlot(
#                         '74e19be1-93cb-4e39-91ec-d891821614d9',
#                         [{"mode": "markers", "name": "Country", "showlegend": false, "text": ["Denmark", "New Zealand", "Finland", "Singapore", "Sweden", "Switzerland", "Norway", "Netherlands", "Germany", "Luxembourg", "Australia", "Canada", "Hong Kong", "United Kingdom", "Austria", "Belgium", "Estonia", "Iceland", "Japan", "Ireland", "United Arab Emirates", "Uruguay", "France", "Chile", "United States", "Seychelles", "Barbados", "Qatar", "Spain", "South Korea", "Portugal", "Botswana", "Israel", "Lithuania", "Slovenia", "Costa Rica", "Cyprus", "Latvia", "Georgia", "Poland", "Oman", "Rwanda", "Italy", "Malta", "Mauritius", "Saudi Arabia", "Malaysia", "Greece", "Armenia", "Jordan", "Belarus", "Croatia", "Bulgaria", "Hungary", "Jamaica", "Romania", "South Africa", "Tunisia", "Ghana", "Maldives", "Argentina", "Bahrain", "China", "Kuwait", "India", "Morocco", "Timor-Leste", "Trinidad and Tobago", "Turkey", "Colombia", "Ecuador", "Brazil", "Ethiopia", "Kazakhstan", "Peru", "Sri Lanka", "Tanzania", "Indonesia", "Albania", "Algeria", "El Salvador", "Thailand", "Vietnam", "Bosnia and Herzegovina", "Mongolia", "Moldova", "Philippines", "Egypt", "Nepal", "Sierra Leone", "Ukraine", "Zambia", "Bolivia", "Kenya", "Mexico", "Pakistan", "Azerbaijan", "Malawi", "Russia", "Laos", "Togo", "Dominican Republic", "Paraguay", "Angola", "Uganda", "Uzbekistan", "Cameroon", "Guatemala", "Iran", "Lebanon", "Mozambique", "Nigeria", "Tajikistan", "Honduras", "Zimbabwe", "Nicaragua", "Cambodia", "Afghanistan", "Burundi", "Equatorial Guinea", "Sudan"], "type": "scatter", "x": [78.3, 84.1, 75.7, 89.4, 74.9, 82.0, 73.4, 77.0, 73.5, 75.8, 82.6, 78.2, 89.1, 79.3, 73.3, 68.9, 77.7, 77.1, 73.3, 80.9, 76.2, 69.1, 66.0, 76.8, 76.6, 64.3, 61.4, 72.3, 66.9, 74.0, 67.0, 69.6, 74.0, 76.7, 67.8, 65.8, 70.1, 71.9, 77.1, 69.1, 63.6, 70.9, 63.8, 69.5, 74.9, 62.4, 74.7, 59.9, 70.6, 66.0, 61.7, 62.2, 70.2, 66.4, 68.5, 69.7, 58.8, 55.8, 59.4, 56.5, 53.1, 66.3, 59.5, 63.2, 56.5, 63.3, 45.9, 58.3, 64.4, 69.2, 51.3, 53.7, 53.6, 69.6, 67.9, 57.4, 61.7, 67.2, 66.9, 46.9, 61.6, 69.4, 58.8, 62.6, 55.9, 62.0, 64.5, 54.0, 54.2, 48.0, 54.9, 53.5, 42.8, 55.3, 66.0, 54.8, 69.3, 52.8, 61.0, 55.5, 54.1, 60.9, 63.0, 52.2, 59.5, 57.2, 53.6, 64.0, 49.2, 51.7, 50.5, 57.2, 52.2, 61.1, 43.1, 57.2, 57.3, 54.7, 49.0, 48.3, 45.0], "y": [88, 88, 85, 85, 85, 85, 84, 82, 80, 80, 77, 77, 77, 77, 76, 76, 75, 75, 74, 72, 71, 71, 69, 67, 67, 66, 64, 63, 62, 61, 61, 60, 60, 60, 60, 57, 57, 57, 56, 56, 54, 54, 53, 53, 53, 53, 51, 50, 49, 49, 47, 47, 44, 44, 44, 44, 44, 44, 43, 43, 42, 42, 42, 42, 40, 40, 40, 40, 40, 39, 39, 38, 38, 38, 38, 38, 38, 37, 36, 36, 36, 36, 36, 35, 35, 34, 34, 33, 33, 33, 33, 33, 31, 31, 31, 31, 30, 30, 30, 29, 29, 28, 28, 27, 27, 26, 25, 25, 25, 25, 25, 25, 25, 24, 24, 22, 21, 19, 19, 16, 16]}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>OLS trendline</b><br>Transparency = 1.571258 * Economical Freedom + -53.511496<br>R<sup>2</sup>=0.672545<br><br>Economical Freedom=%{x}<br>Transparency=%{y} <b>(trend)</b>", "legendgroup": "", "marker": {"color": "#FA636E", "symbol": "circle"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [42.8, 43.1, 45.0, 45.9, 46.9, 48.0, 48.3, 49.0, 49.2, 50.5, 51.3, 51.7, 52.2, 52.2, 52.8, 53.1, 53.5, 53.6, 53.6, 53.7, 54.0, 54.1, 54.2, 54.7, 54.8, 54.9, 55.3, 55.5, 55.8, 55.9, 56.5, 56.5, 57.2, 57.2, 57.2, 57.3, 57.4, 58.3, 58.8, 58.8, 59.4, 59.5, 59.5, 59.9, 60.9, 61.0, 61.1, 61.4, 61.6, 61.7, 61.7, 62.0, 62.2, 62.4, 62.6, 63.0, 63.2, 63.3, 63.6, 63.8, 64.0, 64.3, 64.4, 64.5, 65.8, 66.0, 66.0, 66.0, 66.3, 66.4, 66.9, 66.9, 67.0, 67.2, 67.8, 67.9, 68.5, 68.9, 69.1, 69.1, 69.2, 69.3, 69.4, 69.5, 69.6, 69.6, 69.7, 70.1, 70.2, 70.6, 70.9, 71.9, 72.3, 73.3, 73.3, 73.4, 73.5, 74.0, 74.0, 74.7, 74.9, 74.9, 75.7, 75.8, 76.2, 76.6, 76.7, 76.8, 77.0, 77.1, 77.1, 77.7, 78.2, 78.3, 79.3, 80.9, 82.0, 82.6, 84.1, 89.1, 89.4], "xaxis": "x", "y": [13.738363833540156, 14.209741357058071, 17.19513233933821, 18.609264909891955, 20.1805 ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f
# 0.8200883822270526
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     244.4
# Date:                Tue, 11 May 2021   Prob (F-statistic):           1.26e-30
# Time:                        22:46:28   Log-Likelihood:                -461.62
# No. Observations:                 121   AIC:                             927.2
# Df Residuals:                     119   BIC:                             932.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -53.5115      6.537     -8.186      0.000     -66.456     -40.567
# x1             1.5713      0.101     15.634      0.000       1.372       1.770
# ==============================================================================
# Omnibus:                        3.921   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.274
# Skew:                           0.060   Prob(JB):                        0.321
# Kurtosis:                       2.339   Cond. No.                         423.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
